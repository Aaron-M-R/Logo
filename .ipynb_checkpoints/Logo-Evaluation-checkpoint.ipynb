# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import openpyxl

# %%
df = pd.read_excel('LogoComparisonData.xlsx')

# %%
df.head()
# Out:
#                          Applicant Logo Previous Logo      SSIM  \
# 0  GiorgoArmani DunkinDonuts (fake).png     gucci.png  0.422474
# 1  GiorgoArmani DunkinDonuts (fake).png     venus.png  0.363483
# 2  GiorgoArmani DunkinDonuts (fake).png  t-mobile.png  0.397332
# 3  GiorgoArmani DunkinDonuts (fake).png  drpepper.png  0.315049
# 4  GiorgoArmani DunkinDonuts (fake).png        lv.png  0.378743
#
#    Color Similarity Score  Shape Complexity Score  Template Matching  \
# 0               49.788772                0.856932           0.092365
# 1               43.027191                0.932490           0.124720
# 2               26.913052                0.873433           0.132396
# 3               17.180655                0.876244           0.118946
# 4               38.462226                0.859287           0.119022
#
#    Text Similarity Score
# 0                     11
# 1                     17
# 2                     16
# 3                     16
# 4                      0

# %% [markdown]
# ## Text Similarity Issue
# For this test Text Similarity Score ended up being a way better indicator than it usually is because name of original logo is in the title of the counterfeit. I decided to use Text Similarity being 100 as an indicator of a logo match. Although I'm sure it's not precise, it's just what I did for this first analysis. I created a column called 'match' and made the entries True if text similarity is 100, False otherwise.
#
# For the next test I will prevent the code from comparing a counterfeit's name to anything since it's a giveaway. Then we can incorporate text similarity into the classification. Right now it's not playing a part.

# %%
df = df.assign(Match = lambda x: (x['Text Similarity Score'] == 100))
df
# Out:
#                              Applicant Logo               Previous Logo  \
# 0      GiorgoArmani DunkinDonuts (fake).png                   gucci.png
# 1      GiorgoArmani DunkinDonuts (fake).png                   venus.png
# 2      GiorgoArmani DunkinDonuts (fake).png                t-mobile.png
# 3      GiorgoArmani DunkinDonuts (fake).png                drpepper.png
# 4      GiorgoArmani DunkinDonuts (fake).png                      lv.png
# ...                                     ...                         ...
# 14269                   greyhound(fake).png           samsung(fake).png
# 14270                   greyhound(fake).png        tokyo2020 (fake).png
# 14271                   greyhound(fake).png  Chanel Champion (fake).png
# 14272                   greyhound(fake).png       Puma Gucci (fake).png
# 14273                   greyhound(fake).png           windows(fake).png
#
#            SSIM  Color Similarity Score  Shape Complexity Score  \
# 0      0.422474               49.788772                0.856932
# 1      0.363483               43.027191                0.932490
# 2      0.397332               26.913052                0.873433
# 3      0.315049               17.180655                0.876244
# 4      0.378743               38.462226                0.859287
# ...         ...                     ...                     ...
# 14269  0.542770               24.406560                0.902102
# 14270  0.592169               18.731523                0.901187
# 14271  0.667509               24.107286                0.863101
# 14272  0.603062                4.633276                0.875855
# 14273  0.626470               11.974352                0.884284
#
#        Template Matching  Text Similarity Score  Match
# 0               0.092365                     11  False
# 1               0.124720                     17  False
# 2               0.132396                     16  False
# 3               0.118946                     16  False
# 4               0.119022                      0  False
# ...                  ...                    ...    ...
# 14269           0.098706                     54  False
# 14270           0.074972                     50  False
# 14271           0.081106                     47  False
# 14272           0.093654                     48  False
# 14273           0.088455                     54  False
#
# [14274 rows x 8 columns]

# %% [markdown]
# ## Now check that all the data are present and the right type

# %%
df.head()
# Out:
#                          Applicant Logo Previous Logo      SSIM  \
# 0  GiorgoArmani DunkinDonuts (fake).png     gucci.png  0.422474
# 1  GiorgoArmani DunkinDonuts (fake).png     venus.png  0.363483
# 2  GiorgoArmani DunkinDonuts (fake).png  t-mobile.png  0.397332
# 3  GiorgoArmani DunkinDonuts (fake).png  drpepper.png  0.315049
# 4  GiorgoArmani DunkinDonuts (fake).png        lv.png  0.378743
#
#    Color Similarity Score  Shape Complexity Score  Template Matching  \
# 0               49.788772                0.856932           0.092365
# 1               43.027191                0.932490           0.124720
# 2               26.913052                0.873433           0.132396
# 3               17.180655                0.876244           0.118946
# 4               38.462226                0.859287           0.119022
#
#    Text Similarity Score  Match
# 0                     11  False
# 1                     17  False
# 2                     16  False
# 3                     16  False
# 4                      0  False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14274 entries, 0 to 14273
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Applicant Logo          14274 non-null  object
#  1   Previous Logo           14274 non-null  object
#  2   SSIM                    14274 non-null  float64
#  3   Color Similarity Score  14274 non-null  float64
#  4   Shape Complexity Score  14274 non-null  float64
#  5   Template Matching       14274 non-null  float64
#  6   Text Similarity Score   14274 non-null  int64
#  7   Match                   14274 non-null  bool
# dtypes: bool(1), float64(4), int64(1), object(2)
# memory usage: 794.7+ KB

# %%
#checking for null values
df.isnull().sum()
# Out:
# Applicant Logo            0
# Previous Logo             0
# SSIM                      0
# Color Similarity Score    0
# Shape Complexity Score    0
# Template Matching         0
# Text Similarity Score     0
# Match                     0
# dtype: int64

# %% [markdown]
# # Data visualization

# %%
df.head()
# Out:
#                          Applicant Logo Previous Logo      SSIM  \
# 0  GiorgoArmani DunkinDonuts (fake).png     gucci.png  0.422474
# 1  GiorgoArmani DunkinDonuts (fake).png     venus.png  0.363483
# 2  GiorgoArmani DunkinDonuts (fake).png  t-mobile.png  0.397332
# 3  GiorgoArmani DunkinDonuts (fake).png  drpepper.png  0.315049
# 4  GiorgoArmani DunkinDonuts (fake).png        lv.png  0.378743
#
#    Color Similarity Score  Shape Complexity Score  Template Matching  \
# 0               49.788772                0.856932           0.092365
# 1               43.027191                0.932490           0.124720
# 2               26.913052                0.873433           0.132396
# 3               17.180655                0.876244           0.118946
# 4               38.462226                0.859287           0.119022
#
#    Text Similarity Score  Match
# 0                     11  False
# 1                     17  False
# 2                     16  False
# 3                     16  False
# 4                      0  False

# %% [markdown]
# ## Obviously the data are super imbalanced. What's the expected rate of fraud in future logos? Does it matter?

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))

ax[0] = df['Match'].value_counts().plot.pie(explode=[0,0],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Logo Matching')


#f, ax = plt.subplots(figsize=(6, 8))
ax[1] = sns.countplot(x="Match", data=df, palette="Set1")
ax[1].set_title("Finding Matching Logos")

plt.show()

# %%
df['Match'].value_counts()/len(df)
# Out:
# Match
# False    0.997128
# True     0.002872
# Name: count, dtype: float64

# %%
is_a_match = df[df['Match'] == True]
not_a_match = df[df['Match'] == False]
print ("There are", is_a_match.shape[0], "matches among",  not_a_match.shape[0], "original logos")
# Out:
# There are 41 matches among 14233 original logos

# %% [markdown]
# Since it is highy imbalanced  the machine learning algorithm we use may get biased. It would underpredict the minority, which is exactly the opposite of what we're trying to do. We will try to balance this dataset later .

# %% [markdown]
# Now let's visualize the average similarity scores for matching and non matching logo comparisons

# %%
# Group together the approved logos and the flagged logos
grouped = df.groupby('Match').mean(numeric_only=True)

# Change index from boolean to meaning
grouped = grouped.rename(index = {True: 'Flagged', False: 'Approved'})

# Make every score on a scale from 0-100
grouped['SSIM'] *= 100
grouped['Shape Complexity Score'] *= 100
grouped['Template Matching'] *= 100
grouped
# Out:
#                SSIM  Color Similarity Score  Shape Complexity Score  \
# Match
# Approved  32.120523               32.424638               82.108918
# Flagged   49.174078               22.783697               87.169349
#
#           Template Matching  Text Similarity Score
# Match
# Approved          12.900351              26.207897
# Flagged           12.928492             100.000000

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))

ax[0] = df['Match'].value_counts().plot.pie(explode=[0,0],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Logo Matching')


#f, ax = plt.subplots(figsize=(6, 8))
ax[1] = sns.countplot(x="Match", data=df, palette="Set1")
ax[1].set_title("Finding Matching Logos")

plt.show()

# %%
grouped
# Out:
#                SSIM  Color Similarity Score  Shape Complexity Score  \
# Match
# Approved  32.120523               32.424638               82.108918
# Flagged   49.174078               22.783697               87.169349
#
#           Template Matching  Text Similarity Score
# Match
# Approved          12.900351              26.207897
# Flagged           12.928492             100.000000

# %%
ind = np.arange(4)  
width = 0.3

plt.figure(figsize=(10, 8))
  
xvals = grouped.loc['Approved'][:4]
bar1 = plt.bar(ind, xvals, width, color = 'g') 
  
yvals = grouped.loc['Flagged'][:4]
bar2 = plt.bar(ind+width, yvals, width, color='r') 
  
plt.xlabel('Types of Scores') 
plt.ylabel('Scores (0-100)') 
plt.title('Average Similarity Between Approved and Flagged') 
  
plt.xticks(ind+width,['SSIM', 'Color Similarity Score', 'Shape Similarity Score', 'Template Matching']) 
plt.legend( (bar1, bar2), ('Approved', 'Flagged'), loc='upper left', fontsize=30) 
plt.show()

# %%
df.head()
# Out:
#                          Applicant Logo Previous Logo      SSIM  \
# 0  GiorgoArmani DunkinDonuts (fake).png     gucci.png  0.422474
# 1  GiorgoArmani DunkinDonuts (fake).png     venus.png  0.363483
# 2  GiorgoArmani DunkinDonuts (fake).png  t-mobile.png  0.397332
# 3  GiorgoArmani DunkinDonuts (fake).png  drpepper.png  0.315049
# 4  GiorgoArmani DunkinDonuts (fake).png        lv.png  0.378743
#
#    Color Similarity Score  Shape Complexity Score  Template Matching  \
# 0               49.788772                0.856932           0.092365
# 1               43.027191                0.932490           0.124720
# 2               26.913052                0.873433           0.132396
# 3               17.180655                0.876244           0.118946
# 4               38.462226                0.859287           0.119022
#
#    Text Similarity Score  Match
# 0                     11  False
# 1                     17  False
# 2                     16  False
# 3                     16  False
# 4                      0  False

# %% [markdown]
# We see people who have done masters are earning less than students who have just cleared their high school which is not normal. Let's try to observe more on these people

# %% [markdown]
# ### Checking the individual similarity scores for outliers

# %%
features = ['SSIM', 'Color Similarity Score', 'Shape Complexity Score', 'Template Matching']

for i in features:
    plt.figure(figsize=[15, 5])
    sns.boxplot(x = df[i][1:],data=df.iloc[1:], order=df[i][1:].value_counts().index, palette='Set1')
    plt.title("Boxchart of {}".format(i), fontsize=30)
    plt.show()

# %%
for i in features:
    sns.histplot(x=df[i], palette='Set1',bins=20)
    plt.title("Histogram of {}".format(i))
    plt.show()
# Out:
# /var/folders/04/m_rmq6013ln6qkmx48cqwnjh0000gn/T/ipykernel_28936/819431307.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=df[i], palette='Set1',bins=20)
# /var/folders/04/m_rmq6013ln6qkmx48cqwnjh0000gn/T/ipykernel_28936/819431307.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=df[i], palette='Set1',bins=20)
# /var/folders/04/m_rmq6013ln6qkmx48cqwnjh0000gn/T/ipykernel_28936/819431307.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=df[i], palette='Set1',bins=20)
# /var/folders/04/m_rmq6013ln6qkmx48cqwnjh0000gn/T/ipykernel_28936/819431307.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=df[i], palette='Set1',bins=20)

# %%
distributions = df.copy()[['SSIM', 'Color Similarity Score', 'Shape Complexity Score', 'Template Matching', 'Match']]
distributions
# Out:
#            SSIM  Color Similarity Score  Shape Complexity Score  \
# 0      0.422474               49.788772                0.856932
# 1      0.363483               43.027191                0.932490
# 2      0.397332               26.913052                0.873433
# 3      0.315049               17.180655                0.876244
# 4      0.378743               38.462226                0.859287
# ...         ...                     ...                     ...
# 14269  0.542770               24.406560                0.902102
# 14270  0.592169               18.731523                0.901187
# 14271  0.667509               24.107286                0.863101
# 14272  0.603062                4.633276                0.875855
# 14273  0.626470               11.974352                0.884284
#
#        Template Matching  Match
# 0               0.092365  False
# 1               0.124720  False
# 2               0.132396  False
# 3               0.118946  False
# 4               0.119022  False
# ...                  ...    ...
# 14269           0.098706  False
# 14270           0.074972  False
# 14271           0.081106  False
# 14272           0.093654  False
# 14273           0.088455  False
#
# [14274 rows x 5 columns]

# %%
sns.pairplot(data=distributions, hue='Match')
plt.title('Distributions for each variable')
plt.show()
# Out:
# /Users/aaronrasin/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Normalizing the variables

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df.head()
# Out:
#                          Applicant Logo Previous Logo      SSIM  \
# 0  GiorgoArmani DunkinDonuts (fake).png     gucci.png  0.422474
# 1  GiorgoArmani DunkinDonuts (fake).png     venus.png  0.363483
# 2  GiorgoArmani DunkinDonuts (fake).png  t-mobile.png  0.397332
# 3  GiorgoArmani DunkinDonuts (fake).png  drpepper.png  0.315049
# 4  GiorgoArmani DunkinDonuts (fake).png        lv.png  0.378743
#
#    Color Similarity Score  Shape Complexity Score  Template Matching  \
# 0               49.788772                0.856932           0.092365
# 1               43.027191                0.932490           0.124720
# 2               26.913052                0.873433           0.132396
# 3               17.180655                0.876244           0.118946
# 4               38.462226                0.859287           0.119022
#
#    Text Similarity Score  Match
# 0                     11  False
# 1                     17  False
# 2                     16  False
# 3                     16  False
# 4                      0  False

# %%
scaler.fit(df.drop(['Applicant Logo','Previous Logo', 'Text Similarity Score', 'Match'],axis=1))
# Out:
# MinMaxScaler()

# %%
scaled_features = scaler.transform(df.drop(['Applicant Logo','Previous Logo', 'Text Similarity Score', 'Match'],axis=1))

# %%
# Numeric columns
columns=list(df.columns.values)[2:-2]
columns
# Out:
# ['SSIM',
#  'Color Similarity Score',
#  'Shape Complexity Score',
#  'Template Matching']

# %%
df_scaled = pd.DataFrame(scaled_features,columns=columns)
df_scaled.head()
# Out:
#        SSIM  Color Similarity Score  Shape Complexity Score  Template Matching
# 0  0.683924                0.568800                0.856932           0.186135
# 1  0.641856                0.491554                0.932490           0.245588
# 2  0.665994                0.307462                0.873433           0.259693
# 3  0.607317                0.196276                0.876244           0.234979
# 4  0.652738                0.439403                0.859287           0.235118

# %% [markdown]
# # Handling Imbalanced dataset

# %%
import sklearn
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 1.2.2.

# %%
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import NearMiss

# %%
f,ax=plt.subplots(1,2,figsize=(10,5))

ax[0] = df['Match'].value_counts().plot.pie(explode=[0,0],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Is it a match?')

ax[1] = sns.countplot(x="Match", data=df, palette="Set1")
ax[1].set_title("Is this a match?")

plt.show()

# %% [markdown]
# ### Using over sampling method to handle imbalanced dataset

# %%
df.head()
# Out:
#                          Applicant Logo Previous Logo      SSIM  \
# 0  GiorgoArmani DunkinDonuts (fake).png     gucci.png  0.422474
# 1  GiorgoArmani DunkinDonuts (fake).png     venus.png  0.363483
# 2  GiorgoArmani DunkinDonuts (fake).png  t-mobile.png  0.397332
# 3  GiorgoArmani DunkinDonuts (fake).png  drpepper.png  0.315049
# 4  GiorgoArmani DunkinDonuts (fake).png        lv.png  0.378743
#
#    Color Similarity Score  Shape Complexity Score  Template Matching  \
# 0               49.788772                0.856932           0.092365
# 1               43.027191                0.932490           0.124720
# 2               26.913052                0.873433           0.132396
# 3               17.180655                0.876244           0.118946
# 4               38.462226                0.859287           0.119022
#
#    Text Similarity Score  Match
# 0                     11  False
# 1                     17  False
# 2                     16  False
# 3                     16  False
# 4                      0  False

# %%
X = df_scaled
y= df.Match
X.head()
# Out:
#        SSIM  Color Similarity Score  Shape Complexity Score  Template Matching
# 0  0.683924                0.568800                0.856932           0.186135
# 1  0.641856                0.491554                0.932490           0.245588
# 2  0.665994                0.307462                0.873433           0.259693
# 3  0.607317                0.196276                0.876244           0.234979
# 4  0.652738                0.439403                0.859287           0.235118

# %%
# Implementing Oversampling for Handling Imbalanced 
smk = SMOTETomek(random_state=42)
X_res,y_res=smk.fit_resample(X,y)

# %%
X_res.shape,y_res.shape
# Out:
# ((28464, 4), (28464,))

# %%
from collections import Counter
print('Original dataset shape {}'.format(Counter(y)))
print('Resampled dataset shape {}'.format(Counter(y_res)))
# Out:
# Original dataset shape Counter({False: 14233, True: 41})
# Resampled dataset shape Counter({False: 14232, True: 14232})

# %% [markdown]
# # Split the data into training and testing sets

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res,y_res,test_size=0.20,random_state=101,shuffle=True)

# %%
print("X_train shape:",X_train.shape)
print("X_test shape:",X_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
# Out:
# X_train shape: (22771, 4)
# X_test shape: (5693, 4)
# y_train shape: (22771,)
# y_test shape: (5693,)

# %%
# To store results of models
result_dict_train = {}
result_dict_test = {}

# %% [markdown]
# # Building Models

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
# Out:
# CPU times: user 24 µs, sys: 2 µs, total: 26 µs
# Wall time: 56.7 µs

# %%
# %%time
gradient_booster = GradientBoostingClassifier(learning_rate=0.1)
accuracies = cross_val_score(gradient_booster, X_train, y_train, cv=5)
gradient_booster.fit(X_train,y_train)

print("Train Score:",np.mean(accuracies))
print("Test Score:",gradient_booster.score(X_test,y_test))
# Out:
# Train Score: 0.75394328264107
# Test Score: 0.7568238213399504
# CPU times: user 23.5 s, sys: 28.4 ms, total: 23.5 s
# Wall time: 23.5 s

# %%
result_dict_train["Gradient-Boost Default Train Score"] = np.mean(accuracies)
result_dict_test["Gradient-Boost Default Test Score"] = gradient_booster.score(X_test,y_test)
# Out:
# CPU times: user 11.3 ms, sys: 2.88 ms, total: 14.2 ms
# Wall time: 12.4 ms

# %%
# %%time
grid = {
    'learning_rate':[0.01,0.05,0.1],
    'n_estimators':np.arange(100,500,100),
}

gb = GradientBoostingClassifier()
gb_cv = GridSearchCV(gb, grid, cv = 4)
gb_cv.fit(X_train,y_train)
print("Best Parameters:",gb_cv.best_params_)
print("Train Score:",gb_cv.best_score_)
print("Test Score:",gb_cv.score(X_test,y_test))
# Out:
# Best Parameters: {'learning_rate': 0.1, 'n_estimators': 400}
# Train Score: 0.8360953562566465
# Test Score: 0.837646224742999
# CPU times: user 7min 17s, sys: 256 ms, total: 7min 17s
# Wall time: 7min 17s

# %%
result_dict_train["Gradient-Boost GridSearch Train Score"] = gb_cv.best_score_
result_dict_test["Gradient-Boost GridSearch Test Score"] = gb_cv.score(X_test,y_test)
# Out:
# CPU times: user 86.1 ms, sys: 79 µs, total: 86.2 ms
# Wall time: 84.2 ms

# %% [markdown]
# ## Support Vector Classification (SVC)

# %%
# %%time
from sklearn.svm import SVC
svc = SVC(random_state = 101)
accuracies = cross_val_score(svc, X_train, y_train, cv=5)
svc.fit(X_train,y_train)

print("Train Score:",np.mean(accuracies))
print("Test Score:",svc.score(X_test,y_test))
# Out:
# Train Score: 0.6894718069916859
# Test Score: 0.7008153137185396
# CPU times: user 1min 40s, sys: 349 ms, total: 1min 40s
# Wall time: 1min 40s

# %%
# %%time
result_dict_train["SVM Default Train Score"] = np.mean(accuracies)
result_dict_test["SVM Default Test Score"] = svc.score(X_test,y_test)
# Out:
# CPU times: user 4.4 s, sys: 4.03 ms, total: 4.41 s
# Wall time: 4.4 s

# %%
# ### WARNING! Long Runtime ###

# grid = {
#     'C':[0.01,0.1,1,10],
#     'kernel' : ["linear","poly","rbf","sigmoid"],
#     'degree' : [1,3,5,7],
#     'gamma' : [0.01,1]
# }

# svm  = SVC ()
# svm_cv = GridSearchCV(svm, grid, cv = 5)
# svm_cv.fit(X_train,y_train)
# print("Best Parameters:",svm_cv.best_params_)
# print("Train Score:",svm_cv.best_score_)
# print("Test Score:",svm_cv.score(X_test,y_test))

# %% [markdown]
# ## Naive Bayes

# %%
# %%time
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
accuracies = cross_val_score(classifier, X_train, y_train, cv=5)
classifier.fit(X_train, y_train)

print("Train Score:",np.mean(accuracies))
print("Test Score:",classifier.score(X_test,y_test))
# Out:
# Train Score: 0.6279244197901773
# Test Score: 0.6348812477844736
# CPU times: user 98.7 ms, sys: 4.11 ms, total: 103 ms
# Wall time: 100 ms

# %%
# %%time
result_dict_train["Naive Bayes Default Train Score"] = np.mean(accuracies)
result_dict_test["Naive Bayes Default Test Score"] = classifier.score(X_test,y_test)
# Out:
# CPU times: user 7.54 ms, sys: 2.6 ms, total: 10.1 ms
# Wall time: 8.02 ms

# %% [markdown]
# ## Logistic Regression

# %%
# %%time
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression(max_iter=5000)
accuracies = cross_val_score(lr_model, X_train, y_train, cv=5)
lr_model.fit(X_train, y_train)

print("Train Score:",np.mean(accuracies))
print("Test Score:",lr_model.score(X_test,y_test))
# Out:
# Train Score: 0.5965078484928246
# Test Score: 0.5948245303084013
# CPU times: user 6.27 s, sys: 56.6 s, total: 1min 2s
# Wall time: 30.8 s

# %%
# %%time
result_dict_train["Logistic regression Default Train Score"] = np.mean(accuracies)
result_dict_test["Logistic regression Default Test Score"] = lr_model.score(X_test,y_test)
# Out:
# CPU times: user 39.8 ms, sys: 357 ms, total: 397 ms
# Wall time: 200 ms

# %%
# %%time
c_space = np.logspace(-5, 8, 15)
param_grid = {'C': c_space}
  
# Instantiating logistic regression classifier
logreg = LogisticRegression(max_iter=4000)
  
# Instantiating the GridSearchCV object
logreg_cv = GridSearchCV(logreg, param_grid, cv = 5)
logreg_cv.fit(X_train, y_train)

print("Best Parameters:",logreg_cv.best_params_)
print("Train Score:",logreg_cv.best_score_)
print("Test Score:",logreg_cv.score(X_test,y_test))

# %%
result_dict_train["Logistic Regression GridSearch Train Score"] = logreg_cv.best_score_
result_dict_test["Logistic Regression GridSearch Test Score"] = logreg_cv.score(X_test,y_test)

# %% [markdown]
# ## Decision Tree
# Decision tree so far has the most accurate predictions. See below for implementation and visualization.

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn import metrics

# %%
# %%time
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9761110135253821
# CPU times: user 146 ms, sys: 5.46 ms, total: 151 ms
# Wall time: 154 ms

# %%
# tree_entropy = tree.DecisionTreeClassifier(criterion = 'entropy', 
#                                            random_state = 100, 
#                                            max_depth = 3, 
#                                            min_samples_leaf = 5)


# tree_entropy(X_train, y_train)

# %%
## Predicting logo match using decision tree classifier
# match_predictions = tree_entropy.predict(X_test)
# score = accuracy_score(y_test, match_predictions)
# print("Test Score:", score*100)

# %% [markdown]
# ## Decision Tree Visualization

# %%
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_0 <= 0.34
# |   |--- feature_1 <= 0.23
# |   |   |--- feature_3 <= 0.77
# |   |   |   |--- feature_3 <= 0.69
# |   |   |   |   |--- feature_3 <= 0.67
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  0.67
# |   |   |   |   |   |--- feature_0 <= 0.31
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  0.31
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  0.69
# |   |   |   |   |--- feature_2 <= 0.34
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  0.34
# |   |   |   |   |   |--- feature_2 <= 0.42
# |   |   |   |   |   |   |--- feature_0 <= 0.18
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  0.18
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_2 >  0.42
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_3 >  0.77
# |   |   |   |--- feature_1 <= 0.15
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_1 >  0.15
# |   |   |   |   |--- feature_2 <= 0.38
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  0.38
# |   |   |   |   |   |--- feature_2 <= 0.64
# |   |   |   |   |   |   |--- feature_1 <= 0.22
# |   |   |   |   |   |   |   |--- feature_0 <= 0.12
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  0.12
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.84
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.84
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.84
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.84
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  0.22
# |   |   |   |   |   |   |   |--- feature_0 <= 0.21
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  0.21
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.29
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.29
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  0.64
# |   |   |   |   |   |   |--- class: 0
# |   |--- feature_1 >  0.23
# |   |   |--- feature_1 <= 0.26
# |   |   |   |--- feature_1 <= 0.26
# |   |   |   |   |--- feature_3 <= 0.86
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  0.86
# |   |   |   |   |   |--- feature_3 <= 0.87
# |   |   |   |   |   |   |--- feature_2 <= 0.33
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  0.33
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  0.87
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_1 >  0.26
# |   |   |   |   |--- class: 1
# |   |   |--- feature_1 >  0.26
# |   |   |   |--- class: 0
# |--- feature_0 >  0.34
# |   |--- feature_0 <= 0.89
# |   |   |--- feature_1 <= 0.15
# |   |   |   |--- feature_3 <= 0.62
# |   |   |   |   |--- feature_2 <= 0.63
# |   |   |   |   |   |--- feature_1 <= 0.04
# |   |   |   |   |   |   |--- feature_0 <= 0.83
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  0.83
# |   |   |   |   |   |   |   |--- feature_2 <= 0.32
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  0.32
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.35
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.87
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.87
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.35
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_1 >  0.04
# |   |   |   |   |   |   |--- feature_2 <= 0.37
# |   |   |   |   |   |   |   |--- feature_2 <= 0.22
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.15
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.12
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.12
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.15
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_2 >  0.22
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.13
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.13
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.38
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.38
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |--- feature_2 >  0.37
# |   |   |   |   |   |   |   |--- feature_1 <= 0.13
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.13
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.49
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.49
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.52
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.52
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  0.63
# |   |   |   |   |   |--- feature_0 <= 0.52
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  0.52
# |   |   |   |   |   |   |--- feature_3 <= 0.06
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  0.06
# |   |   |   |   |   |   |   |--- feature_1 <= 0.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.09
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.83
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.83
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.09
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.42
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.42
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |--- feature_3 >  0.62
# |   |   |   |   |--- feature_3 <= 0.73
# |   |   |   |   |   |--- feature_2 <= 0.70
# |   |   |   |   |   |   |--- feature_1 <= 0.13
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  0.13
# |   |   |   |   |   |   |   |--- feature_2 <= 0.32
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  0.32
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.48
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.48
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  0.70
# |   |   |   |   |   |   |--- feature_2 <= 0.79
# |   |   |   |   |   |   |   |--- feature_1 <= 0.06
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.84
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.84
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  0.06
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.77
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.77
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  0.79
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  0.73
# |   |   |   |   |   |--- feature_1 <= 0.10
# |   |   |   |   |   |   |--- feature_0 <= 0.87
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  0.87
# |   |   |   |   |   |   |   |--- feature_0 <= 0.87
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  0.87
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_1 >  0.10
# |   |   |   |   |   |   |--- feature_0 <= 0.79
# |   |   |   |   |   |   |   |--- feature_1 <= 0.14
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.14
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.40
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.15
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.15
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.40
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  0.79
# |   |   |   |   |   |   |   |--- feature_1 <= 0.11
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.89
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.89
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.11
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.62
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.86
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.86
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.62
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_1 >  0.15
# |   |   |   |--- feature_2 <= 0.24
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_2 >  0.24
# |   |   |   |   |--- feature_2 <= 0.73
# |   |   |   |   |   |--- feature_3 <= 0.11
# |   |   |   |   |   |   |--- feature_3 <= 0.09
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  0.09
# |   |   |   |   |   |   |   |--- feature_1 <= 0.79
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.79
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.53
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.53
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  0.11
# |   |   |   |   |   |   |--- feature_1 <= 0.88
# |   |   |   |   |   |   |   |--- feature_3 <= 0.87
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.41
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.80
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.80
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.41
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.32
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.32
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |--- feature_3 >  0.87
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.70
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.70
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  0.88
# |   |   |   |   |   |   |   |--- feature_1 <= 0.91
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.47
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.99
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.47
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.67
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.67
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.90
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.90
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.91
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  0.73
# |   |   |   |   |   |--- feature_3 <= 0.90
# |   |   |   |   |   |   |--- feature_3 <= 0.25
# |   |   |   |   |   |   |   |--- feature_1 <= 0.58
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.55
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.55
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.86
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.86
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  0.58
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.79
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.06
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.06
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.94
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.79
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  0.25
# |   |   |   |   |   |   |   |--- feature_0 <= 0.79
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.88
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.29
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.29
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.88
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.75
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.52
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.52
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.75
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  0.79
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.52
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.52
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.68
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.68
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  0.90
# |   |   |   |   |   |   |--- feature_2 <= 0.80
# |   |   |   |   |   |   |   |--- feature_1 <= 0.63
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.63
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.90
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.89
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.89
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.90
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  0.80
# |   |   |   |   |   |   |   |--- class: 0
# |   |--- feature_0 >  0.89
# |   |   |--- feature_3 <= 0.02
# |   |   |   |--- feature_3 <= 0.02
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_3 >  0.02
# |   |   |   |   |--- feature_1 <= 0.09
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_1 >  0.09
# |   |   |   |   |   |--- class: 0
# |   |   |--- feature_3 >  0.02
# |   |   |   |--- feature_2 <= 0.96
# |   |   |   |   |--- feature_0 <= 0.97
# |   |   |   |   |   |--- feature_1 <= 0.13
# |   |   |   |   |   |   |--- feature_1 <= 0.02
# |   |   |   |   |   |   |   |--- feature_3 <= 0.70
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  0.70
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.74
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.60
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.60
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.74
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  0.02
# |   |   |   |   |   |   |   |--- feature_2 <= 0.16
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  0.16
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.91
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.28
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.28
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.91
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- feature_1 >  0.13
# |   |   |   |   |   |   |--- feature_2 <= 0.66
# |   |   |   |   |   |   |   |--- feature_3 <= 0.26
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  0.26
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.57
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.27
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.27
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.57
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.63
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.63
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.67
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.67
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  0.66
# |   |   |   |   |   |   |   |--- feature_1 <= 0.48
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.48
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.66
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.58
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.58
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.66
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.87
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.87
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.91
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.91
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_0 >  0.97
# |   |   |   |   |   |--- feature_3 <= 0.28
# |   |   |   |   |   |   |--- feature_1 <= 0.13
# |   |   |   |   |   |   |   |--- feature_2 <= 0.53
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.15
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.15
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.53
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  0.13
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  0.28
# |   |   |   |   |   |   |--- feature_3 <= 0.61
# |   |   |   |   |   |   |   |--- feature_0 <= 1.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.02
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.02
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.45
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.45
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.39
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |--- feature_0 >  1.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  0.61
# |   |   |   |   |   |   |   |--- feature_2 <= 0.58
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  0.58
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.12
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.92
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.92
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.12
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.67
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.67
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_2 >  0.96
# |   |   |   |   |--- class: 0

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf, 
                   feature_names=features,  
                   class_names=['Match', 'Not a match'],
                   filled=True)

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9901633585104515

# %%
conf_matrix[1][0]
# Out:
# 9

# %%
conf_matrix
# Out:
# array([[2787,   47],
#        [   9, 2850]])

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print('There are {} false positives and {} false negatives'.format(conf_matrix[0][1], conf_matrix[1][0]))
print('sad :(')
# Out:
# There are 47 false positives and 9 false negatives
# sad :(
